# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pip install imblearn
# Out:
# ...
#
# ...

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
file_path = Path('Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# ...

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
pd.options.display.max_rows=100
columns=df.dtypes=='object'
list(columns[columns].index)

list_columns=list(columns[columns].index)
list_columns
# Out:
# ['home_ownership',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'initial_list_status',
#  'next_pymnt_d',
#  'application_type',
#  'hardship_flag',
#  'debt_settlement_flag']

# %%
for i in list_columns:
    le = LabelEncoder()

# Encoding homeowner column
    le.fit(df[i])
    df[i] = le.transform(df[i])

# %%
df.head()
# Out:
#    loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35               3     66000.0
# 1    25000.0    0.2000       929.09               1    105000.0
# 2    20000.0    0.2000       529.88               1     56000.0
# 3    10000.0    0.1640       353.55               3     92000.0
# 4    22000.0    0.1474       520.39               1     52000.0
#
#    verification_status  issue_d  loan_status  pymnt_plan    dti  ...  \
# 0                    1        2            1           0  27.24  ...
# 1                    2        2            1           0  20.23  ...
# 2                    2        2            1           0  24.26  ...
# 3                    2        2            1           0  31.44  ...
# 4                    0        2            1           0  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# ...

# %%
le = LabelEncoder()

# Encoding homeowner column
le.fit(df["verification_status"])
df["verification_status"] = le.transform(df["verification_status"])

df.head()
# Out:
#    loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35               3     66000.0
# 1    25000.0    0.2000       929.09               1    105000.0
# 2    20000.0    0.2000       529.88               1     56000.0
# 3    10000.0    0.1640       353.55               3     92000.0
# 4    22000.0    0.1474       520.39               1     52000.0
#
#    verification_status  issue_d  loan_status  pymnt_plan    dti  ...  \
# 0                    1        2            1           0  27.24  ...
# 1                    2        2            1           0  20.23  ...
# 2                    2        2            1           0  24.26  ...
# 3                    2        2            1           0  31.44  ...
# 4                    0        2            1           0  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# ...

# %%
# Create our features
X= df.drop(columns="loan_status")

# Create our target
y=df["loan_status"]

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment  home_ownership    annual_inc  \
# count  68817.000000  68817.000000  68817.000000    68817.000000  6.881700e+04
# mean   16677.594562      0.127718    480.652863        1.812779  8.821371e+04
# std    10277.348590      0.048130    288.062432        0.941313  1.155800e+05
# min     1000.000000      0.060000     30.890000        0.000000  4.000000e+01
# 25%     9000.000000      0.088100    265.730000        1.000000  5.000000e+04
# 50%    15000.000000      0.118000    404.560000        1.000000  7.300000e+04
# 75%    24000.000000      0.155700    648.100000        3.000000  1.040000e+05
# max    40000.000000      0.308400   1676.230000        3.000000  8.797500e+06
#
#        verification_status       issue_d  pymnt_plan           dti  \
# count         68817.000000  68817.000000     68817.0  68817.000000
# mean              0.669994      0.805542         0.0     21.778153
# ...

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 1    68470
# 0      347
# Name: loan_status, dtype: int64

# %%
# Split the X and y into X_train, X_test, y_train, y_test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X,y, random_state=1,stratify=y)

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
X_scaler = scaler.fit(X_train)

# %%
# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

balanced_random_forest = BalancedRandomForestClassifier(n_estimators=1000, random_state=1)
balanced_random_forest.fit(X_train_scaled, y_train)
# Out:
# BalancedRandomForestClassifier(n_estimators=1000, random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred_brf = balanced_random_forest.predict(X_test_scaled)
balanced_as_brf=balanced_accuracy_score(y_test, y_pred_brf)
print(balanced_as_brf)
# Out:
# 0.7745204684723884

# %%
# Display the confusion matrix
cm_brf = confusion_matrix(y_test, y_pred_brf)
cm_df_brf = pd.DataFrame(
    cm_brf, index=["Actual High Risk", "Actual Low Risk"], columns=["Predicted High Risk", "Predicted Low Risk"]
)
cm_df_brf
# Out:
#                   Predicted High Risk  Predicted Low Risk
# Actual High Risk                   56                  31
# Actual Low Risk                  1620               15498

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred_brf))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.03      0.64      0.91      0.06      0.76      0.57        87
#           1       1.00      0.91      0.64      0.95      0.76      0.60     17118
#
# avg / total       0.99      0.90      0.65      0.94      0.76      0.60     17205

# %%
# List the features sorted in descending order by feature importance
importances = balanced_random_forest.feature_importances_
sorted(zip(balanced_random_forest.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.07191320945389229, 'total_rec_prncp'),
#  (0.06401356232400515, 'total_rec_int'),
#  (0.060417812412970104, 'total_pymnt_inv'),
#  (0.06027369257491616, 'last_pymnt_amnt'),
#  (0.055712550813455414, 'total_pymnt'),
#  (0.029449922851063237, 'int_rate'),
#  (0.02278737054744858, 'issue_d'),
#  (0.01854601936834862, 'dti'),
#  (0.017476773422900736, 'installment'),
#  (0.01716769596338444, 'annual_inc'),
#  (0.01699850540817879, 'max_bal_bc'),
#  (0.01643977147116226, 'mths_since_recent_inq'),
#  (0.01605537986144758, 'out_prncp_inv'),
#  (0.016040423323660888, 'il_util'),
#  (0.01557866004720193, 'out_prncp'),
#  (0.015429004138012856, 'bc_util'),
#  (0.01532432589157398, 'mo_sin_old_il_acct'),
#  (0.015295133278985453, 'revol_bal'),
#  (0.015098642911098314, 'avg_cur_bal'),
#  (0.015085765520124337, 'tot_hi_cred_lim'),
#  (0.014476087969002963, 'all_util'),
#  (0.013971855283338611, 'mo_sin_old_rev_tl_op'),
#  (0.013814898631841679, 'total_bc_limit'),
# ...

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
from imblearn.ensemble import EasyEnsembleClassifier

Easy_Ensemble_Class = EasyEnsembleClassifier(n_estimators=100, random_state=1)
Easy_Ensemble_Class.fit(X_train_scaled, y_train)
# Out:
# EasyEnsembleClassifier(n_estimators=100, random_state=1)

# %%
# Calculated the balanced accuracy score
y_predition_eec = Easy_Ensemble_Class.predict(X_test_scaled)
bas_eec=balanced_accuracy_score(y_test, y_pred_brf)
print(bas_eec)
# Out:
# 0.7745204684723884

# %%
# Display the confusion matrix
cm_eec = confusion_matrix(y_test, y_predition_eec)
cm_df_eec = pd.DataFrame(
    cm_eec, index=["Actual High Risk", "Actual Low Risk"], columns=["Predicted High Risk", "Predicted Low Risk"]
)
cm_df_eec
# Out:
#                   Predicted High Risk  Predicted Low Risk
# Actual High Risk                   79                   8
# Actual Low Risk                  1003               16115

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_predition_eec))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.07      0.91      0.94      0.14      0.92      0.85        87
#           1       1.00      0.94      0.91      0.97      0.92      0.86     17118
#
# avg / total       0.99      0.94      0.91      0.97      0.92      0.86     17205

# %% [markdown]
# ### Final Questions
#
# 1. Which model had the best balanced accuracy score?
#
#   # Both models had the same value. Equally accurate
#
# 2. Which model had the best recall score?
#
#  # The balanced forest appears to have a lower recall score.
#
# 3. Which model had the best geometric mean score?
#
#   # The easy ensemble
#
#
# 4. What are the top three features?
# # Total Debt
# # Borrower Income
# # Debt to Income Ratio
